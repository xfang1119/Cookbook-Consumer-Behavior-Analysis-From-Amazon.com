# %%
# Run in terminal or command prompt
# python3 -m spacy download en
import numpy as np
import pandas as pd
import re, nltk, spacy, gensim
from nltk.corpus import stopwords
# Sklearn
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction import text
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
# gensim
import gensim
from gensim import corpora
import pyLDAvis.gensim
# Plotting tools
from pprint import pprint
import pyLDAvis
import pyLDAvis.sklearn
import matplotlib.pyplot as plt
import glob
# %matplotlib inline

# %%
path = '../../Web_Scraping/Result/book_2clean.csv'
df = pd.read_csv(path)
keywords_list = df.key_words.values.tolist()

# %%
df.head()
# Out:
#    No.                                          book_link  \
# 0    0  https://www.amazon.com/10-Day-Green-Smoothie-C...
# 1    1  https://www.amazon.com/Simon-Schuster-Audio-Th...
# 2    2  https://www.amazon.com/Wheat-Belly-Lose-Weight...
# 3    3  https://www.amazon.com/Thug-Kitchen-Official-C...
# 4    4  https://www.amazon.com/Medical-Medium-Secrets-...
#
#                                                title  \
# 0  10-Day Green Smoothie Cleanse: Lose Up to 15 P...
# 1                                         The Secret
# 2  Wheat Belly: Lose the Wheat, Lose the Weight, ...
# 3  Thug Kitchen: The Official Cookbook: Eat Like ...
# 4  Medical Medium: Secrets Behind Chronic and Mys...
#
#                                               author  star  review_amount  \
# 0                                           JJ Smith   4.7           9207
# 1  Rhonda rne (Author, Narrator), Simon & Schuste...   4.6           6617
# 2                                      William Davis   4.4           5977
# 3                                       Thug Kitchen   4.6           5969
# 4                                    Anthony William   4.6           4177
#
#    kindle_price  paperback_price  hardcover_price  \
# 0         12.99             9.99              NaN
# 1         11.99            13.49             5.75
# 2          6.99            10.28            13.99
# 3          9.99            14.89            14.89
# 4          9.99            16.00            19.30
#
#                                                intro  book_rank  \
# 0  The New York Times bestselling 10-Day Green Sm...        NaN
# 1  It has been passed down through the ages, high...        NaN
# 2  In this #1 New York Times bestseller, a renown...     3272.0
# 3  #1 New York Times Bestseller, first in the bes...      144.0
# 4  Anthony William, Medical Medium, has helped te...      580.0
#
#                                         product_desc  \
# 0                                                NaN
# 1                                                NaN
# 2  Review\n“Fascinating, compelling, and more tha...
# 3  Review\n“Dear reader, I love Thug Kitchen's co...
# 4  Review\n"Within the first three minutes of spe...
#
#                                           abt_author  \
# 0                                                NaN
# 1                                                NaN
# 2  About the Author\nWilliam Davis, MD, is a New ...
# 3  About the Author\nThe Thug Kitchen crew is an ...
# 4                                                NaN
#
#                                            key_words
# 0  ['weight loss', 'lose weight', 'day green', 'h...
# 1  ['law of attraction', 'positive thinking', 'rh...
# 2  ['lose weight', 'gluten free', 'weight loss', ...
# 3  ['thug kitchen', 'easy to follow', 'great reci...
# 4  ['anthony william', 'highly recommend', 'thank...

# %%
keywords_list = df.key_words.values.tolist()

# %%
import ast
for list 
x = ast.literal_eval(x)
x
# Out:
# ['weight loss',
#  'lose weight',
#  'day green',
#  'highly recommend',
#  'eating habits',
#  'modified version',
#  'changed my life',
#  'day cleanse',
#  'really works',
#  'thanks jj smith',
#  'full cleanse',
#  'ten days',
#  'looking forward',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
type(x)
# Out:
# list
